# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(rc={'figure.figsize': [11, 11]}, font_scale=1.2)

# %%
df = pd.read_csv('C:\\Users\\go\\Downloads\\world-happiness-report.csv')

# %%
df.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
# Data analysis

# %%
df.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
df.shape
# Out:
# (1949, 11)

# %%
df.describe().transpose()
# Out:
#                                    count         mean       std       min  \
# year                              1949.0  2013.216008  4.166828  2005.000
# Life Ladder                       1949.0     5.466705  1.115711     2.375
# Log GDP per capita                1913.0     9.368453  1.154084     6.635
# Social support                    1936.0     0.812552  0.118482     0.290
# Healthy life expectancy at birth  1894.0    63.359374  7.510245    32.300
# Freedom to make life choices      1917.0     0.742558  0.142093     0.258
# Generosity                        1860.0     0.000103  0.162215    -0.335
# Perceptions of corruption         1839.0     0.747125  0.186789     0.035
# Positive affect                   1927.0     0.710003  0.107100     0.322
# Negative affect                   1933.0     0.268544  0.085168     0.083
#
#                                          25%        50%       75%       max
# year                              2010.00000  2013.0000  2017.000  2020.000
# ...

# %%
df['Life Ladder'].describe()
# Out:
# count    1949.000000
# mean        5.466705
# std         1.115711
# min         2.375000
# 25%         4.640000
# 50%         5.386000
# 75%         6.283000
# max         8.019000
# Name: Life Ladder, dtype: float64

# %%
df['Life Ladder'].max()
# Out:
# 8.019

# %%
df['Life Ladder'].min()
# Out:
# 2.375

# %%
df[df["Life Ladder"]== 8.019][["Country name","Positive affect",'year']]
# Out:
#     Country name  Positive affect  year
# 449      Denmark             0.86  2005

# %%
df[df["Life Ladder"]== 2.375][["Country name","Positive affect",'year']]
# Out:
#    Country name  Positive affect  year
# 11  Afghanistan            0.351  2019

# %%
df[df["Life Ladder"] > 5.386000][["Country name","Positive affect"]]
# Out:
#      Country name  Positive affect
# 13        Albania            0.640
# 15        Albania            0.628
# 16        Albania            0.607
# 25        Algeria              NaN
# 27        Algeria            0.604
# ...           ...              ...
# 1895      Vietnam            0.588
# 1896      Vietnam            0.665
# 1899      Vietnam            0.532
# 1900      Vietnam            0.615
# 1907      Vietnam            0.751
#
# [973 rows x 2 columns]

# %%
df[df["Life Ladder"] < 5.386000][["Country name","Positive affect"]]
# Out:
#      Country name  Positive affect
# 0     Afghanistan            0.518
# 1     Afghanistan            0.584
# 2     Afghanistan            0.618
# 3     Afghanistan            0.611
# 4     Afghanistan            0.710
# ...           ...              ...
# 1944     Zimbabwe            0.738
# 1945     Zimbabwe            0.806
# 1946     Zimbabwe            0.710
# 1947     Zimbabwe            0.716
# 1948     Zimbabwe            0.703
#
# [973 rows x 2 columns]

# %%
df.groupby('year').describe()['Life Ladder'].transpose()
pivot = pd.pivot_table(values,columns,index)
# Out:
# year        2005       2006        2007        2008        2009        2010  \
# count  27.000000  89.000000  102.000000  110.000000  114.000000  124.000000
# mean    6.446259   5.196899    5.418275    5.418509    5.457667    5.496806
# std     0.919129   1.094545    1.047920    1.169425    1.029690    1.125612
# min     4.719000   3.202000    3.280000    2.808000    3.408000    3.229000
# 25%     5.539000   4.460000    4.670250    4.604250    4.687000    4.640500
# 50%     6.620000   5.084000    5.221500    5.181500    5.360500    5.460500
# 75%     7.161500   5.954000    6.121750    6.235500    6.253750    6.318750
# max     8.019000   7.672000    7.834000    7.971000    7.683000    7.771000
#
# year         2011        2012        2013        2014        2015        2016  \
# count  146.000000  142.000000  137.000000  145.000000  143.000000  142.000000
# mean     5.424082    5.443754    5.394562    5.389021    5.404035    5.399479
# ...

# %%
df['year'].describe()
# Out:
# count    1949.000000
# mean     2013.216008
# std         4.166828
# min      2005.000000
# 25%      2010.000000
# 50%      2013.000000
# 75%      2017.000000
# max      2020.000000
# Name: year, dtype: float64

# %%
df.groupby('Country name').describe()['Life Ladder'].transpose()
# Out:
# Country name  Afghanistan    Albania   Algeria    Angola  Argentina  \
# count           12.000000  13.000000  8.000000  4.000000  15.000000
# mean             3.594667   5.019385  5.389875  4.420250   6.310133
# std              0.740986   0.441690  0.470102  0.815286   0.313529
# min              2.375000   4.511000  4.745000  3.795000   5.793000
# 25%              3.021750   4.634000  5.197500  3.901500   6.056000
# 50%              3.753500   4.995000  5.329000  4.148500   6.424000
# 75%              4.042250   5.365000  5.499250  4.667250   6.525000
# max              4.758000   5.867000  6.355000  5.589000   6.776000
#
# Country name    Armenia  Australia    Austria  Azerbaijan    Bahrain  ...  \
# count         14.000000  14.000000  13.000000   14.000000  11.000000  ...
# mean           4.513571   7.282071   7.242231    4.941000   6.001727  ...
# std            0.378730   0.087167   0.169690    0.354885   0.651335  ...
# ...

# %%
df.corr()['Life Ladder']
# Out:
# year                                0.035515
# Life Ladder                         1.000000
# Log GDP per capita                  0.790166
# Social support                      0.707806
# Healthy life expectancy at birth    0.744506
# Freedom to make life choices        0.528063
# Generosity                          0.190632
# Perceptions of corruption          -0.427245
# Positive affect                     0.532273
# Negative affect                    -0.297488
# Name: Life Ladder, dtype: float64

# %%
### Data Visualization

# %%
df.corr()['Life Ladder']
# Out:
# year                                0.035515
# Life Ladder                         1.000000
# Log GDP per capita                  0.783824
# Social support                      0.705356
# Healthy life expectancy at birth    0.741200
#                                       ...
# Country name_Venezuela              0.043675
# Country name_Vietnam               -0.012266
# Country name_Yemen                 -0.109689
# Country name_Zambia                -0.069775
# Country name_Zimbabwe              -0.125072
# Name: Life Ladder, Length: 175, dtype: float64

# %%
new_df = pd.pivot_table(data=df, values='Life Ladder', columns='year')
new_df
# Out:
# year             2005      2006      2007      2008      2009      2010  \
# Life Ladder  6.446259  5.196899  5.418275  5.418509  5.457667  5.496806
#
# year             2011      2012      2013      2014      2015      2016  \
# Life Ladder  5.424082  5.443754  5.394562  5.389021  5.404035  5.399479
#
# year             2017      2018      2019    2020
# Life Ladder  5.460408  5.499444  5.570868  5.8406

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr()[['Life Ladder','Positive affect']], annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='Log GDP per capita', y='Life Ladder', data=df)

# %%
sns.jointplot(x='Social support', y='Life Ladder', data=df)

# %%
sns.jointplot(x='Healthy life expectancy at birth', y='Life Ladder', data=df)

# %%
sns.jointplot(x= 'Freedom to make life choices', y='Life Ladder', data=df)

# %%
sns.jointplot(data = df,  x='Generosity', y = 'Life Ladder')

# %%
sns.jointplot(data= df, x='Perceptions of corruption' , y= 'Life Ladder')

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
# Data preprocessing¶
# Data Cleaning or Cleansing
# Work with Missing data
# Work with Categorical data
# Split data to Train and Test Sets
# Feature Scaling

# %%
df = pd.get_dummies(df, columns=['Country name'], drop_first=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Columns: 175 entries, year to Country name_Zimbabwe
# dtypes: float64(9), int64(1), uint8(165)
# memory usage: 466.4 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Columns: 175 entries, year to Country name_Zimbabwe
# dtypes: float64(9), int64(1), uint8(165)
# memory usage: 466.4 KB

# %%
df.isna().sum()
# Out:
# year                                0
# Life Ladder                         0
# Log GDP per capita                  0
# Social support                      0
# Healthy life expectancy at birth    0
#                                    ..
# Country name_Venezuela              0
# Country name_Vietnam                0
# Country name_Yemen                  0
# Country name_Zambia                 0
# Country name_Zimbabwe               0
# Length: 175, dtype: int64

# %%
df['Perceptions of corruption'].mean()
# Out:
# 0.7471250679717214

# %%
df['Perceptions of corruption'].fillna(value=df['Perceptions of corruption'].mean(),inplace=True)

# %%
df['Social support'].fillna(value=df['Social support'].mean(),inplace=True)

# %%
df['Freedom to make life choices'].fillna(value=df['Freedom to make life choices'].mean(),inplace=True)

# %%
df['Generosity'].fillna(value=df['Generosity'].mean(),inplace=True)

# %%
df['Healthy life expectancy at birth'].fillna(value=df['Healthy life expectancy at birth'].mean(),inplace=True)

# %%
df['Log GDP per capita'].fillna(value=df['Log GDP per capita'].mean(),inplace=True)

# %%
df['Log GDP per capita'].fillna(value=df['Log GDP per capita'].mean(),inplace=True)

# %%
df['Positive affect'].fillna(value= df['Positive affect'].mean(),inplace =True)

# %%
df['Negative affect'].fillna(value= df['Negative affect'].mean(),inplace =True)

# %%
df.isna().sum()
# Out:
# year                                0
# Life Ladder                         0
# Log GDP per capita                  0
# Social support                      0
# Healthy life expectancy at birth    0
#                                    ..
# Country name_Venezuela              0
# Country name_Vietnam                0
# Country name_Yemen                  0
# Country name_Zambia                 0
# Country name_Zimbabwe               0
# Length: 175, dtype: int64

# %%
df['Life Ladder'].unique()
# Out:
# array([3.724, 4.402, 4.758, ..., 3.638, 3.616, 3.16 ])

# %%
df.isnull().sum()
# Out:
# year                                0
# Life Ladder                         0
# Log GDP per capita                  0
# Social support                      0
# Healthy life expectancy at birth    0
#                                    ..
# Country name_Venezuela              0
# Country name_Vietnam                0
# Country name_Yemen                  0
# Country name_Zambia                 0
# Country name_Zimbabwe               0
# Length: 175, dtype: int64

# %%
# Split data to Train and Test Sets

# %%
x = df.drop('Life Ladder', axis=1)
y = df['Life Ladder']
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
models = {
    "KNNR" : KNeighborsRegressor(), 
    "DT": DecisionTreeRegressor(),
    "RF": RandomForestRegressor(),
}

# %%
for name, model in models.items():
    print(f'Using model: {name}')
    model.fit(x_train, y_train)
    print(f'Training Score: {model.score(x_train, y_train)}')
    print(f'Test Score: {model.score(x_test, y_test)}') 
    y_pred = model.predict(x_test)
    print(f'RMSE: {np.sqrt(mean_squared_error(y_test, y_pred))}')
    print('-----------------------------------------------------------')
# Out:
# Using model: KNNR
# Training Score: 0.8640026824421082
# Test Score: 0.7554516073772568
# RMSE: 0.5481470470875213
# -----------------------------------------------------------
# Using model: DT
# Training Score: 1.0
# Test Score: 0.8082627762763823
# RMSE: 0.4853643674918558
# -----------------------------------------------------------
# Using model: RF
# Training Score: 0.9840206017294667
# Test Score: 0.8896589850203435
# RMSE: 0.3681994706760912
# -----------------------------------------------------------

# %%
### Testing on real data and deployment

# %%
import pickle

# %%
filename = 'model.pkl'

pickle.dump(model, open(filename, 'wb'))

# %%
x.columns
# Out:
# Index(['year', 'Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption', 'Positive affect',
#        'Negative affect', 'Country name_Albania',
#        ...
#        'Country name_United Arab Emirates', 'Country name_United Kingdom',
#        'Country name_United States', 'Country name_Uruguay',
#        'Country name_Uzbekistan', 'Country name_Venezuela',
#        'Country name_Vietnam', 'Country name_Yemen', 'Country name_Zambia',
#        'Country name_Zimbabwe'],
#       dtype='object', length=174)
